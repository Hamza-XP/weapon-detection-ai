# %% [markdown]
# # Weapon Detection Model Training
# This notebook trains a TensorFlow object detection model using your custom dataset

# %% [markdown]
# ## 1. Environment Setup
# Install required dependencies

# %%
# 1. Install Dependencies
# !pip install tensorflow==2.12.0
# !pip install tensorflow-object-detection-api
# !pip install protobuf==3.20.3
# !pip install pycocotools
# !pip install pandas

# 2. Clone TF Models
# !git clone --depth 1 https://github.com/tensorflow/models

# 3. Compile Protobufs
# !cd models/research && protoc object_detection/protos/*.proto --python_out=.



# !rmdir /s/q models

# Clean up previous installations
# !del setup.py
# !del -r training
# !del -r ssd_mobilenet*
# 4. Install Object Detection API
# !cp models/research/object_detection/packages/tf2/setup.py .
# !python -m pip install . --no-deps

# 5. Add to Python Path
import sys
sys.path.append('models/research')
sys.path.append('models/research/object_detection')

# 6. Verify Installation
# !python models/research/object_detection/builders/model_builder_tf2_test.py

# 7. Restart Kernel After Installation
print("Please restart the kernel now! (Kernel > Restart Kernel)")
# Out:
# Requirement already satisfied: tensorflow==2.12.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.17.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.13.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (25.2.10)
# Requirement already satisfied: jax>=0.3.15 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.0.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: packaging in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (24.2)
# Requirement already satisfied: setuptools in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (57.4.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (18.1.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.31.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.13.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.71.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.20.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.45.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.5.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: scipy>=1.9 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.15.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.39.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.32.3)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.1.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.10)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.0.2)
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\ih20g\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: tensorflow-object-detection-api in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (0.1.1)
# Requirement already satisfied: Protobuf in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (3.20.3)
# Requirement already satisfied: Matplotlib>=2.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (3.10.1)
# Requirement already satisfied: twine in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (6.1.0)
# Requirement already satisfied: jupyter in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (1.1.1)
# Requirement already satisfied: Cython>=0.28.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (3.0.12)
# Requirement already satisfied: Pillow>=1.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (11.2.1)
# Requirement already satisfied: lxml in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (5.3.2)
# Requirement already satisfied: wheel in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (0.45.1)
# Requirement already satisfied: tensorflow in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (2.12.0)
# Requirement already satisfied: contextlib2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-object-detection-api) (21.6.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (0.12.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.23.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from Matplotlib>=2.1->tensorflow-object-detection-api) (24.2)
# Requirement already satisfied: six>=1.5 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->Matplotlib>=2.1->tensorflow-object-detection-api) (1.17.0)
# Requirement already satisfied: nbconvert in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (7.16.6)
# Requirement already satisfied: jupyterlab in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (4.4.0)
# Requirement already satisfied: ipykernel in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from jupyter->tensorflow-object-detection-api) (6.29.5)
# Requirement already satisfied: jupyter-console in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (6.6.3)
# Requirement already satisfied: notebook in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (7.4.0)
# Requirement already satisfied: ipywidgets in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter->tensorflow-object-detection-api) (8.1.6)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.14.3)
# Requirement already satisfied: nest-asyncio in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (1.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (5.7.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (0.1.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (8.35.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (26.4.0)
# Requirement already satisfied: psutil in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (7.0.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from ipykernel->jupyter->tensorflow-object-detection-api) (6.4.2)
# Requirement already satisfied: decorator in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (5.2.1)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (4.13.2)
# Requirement already satisfied: colorama in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.19.2)
# Requirement already satisfied: exceptiongroup in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (1.2.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.6.3)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (3.0.50)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tensorflow-object-detection-api) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\ih20g\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tensorflow-object-detection-api) (310)
# Requirement already satisfied: wcwidth in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.2.13)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter->tensorflow-object-detection-api) (3.0.14)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (0.2.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (2.27.3)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (3.1.6)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (2.2.1)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (57.4.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (2.2.5)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab->jupyter->tensorflow-object-detection-api) (0.28.1)
# Requirement already satisfied: certifi in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tensorflow-object-detection-api) (2025.1.31)
# Requirement already satisfied: idna in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tensorflow-object-detection-api) (3.10)
# Requirement already satisfied: anyio in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tensorflow-object-detection-api) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tensorflow-object-detection-api) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->tensorflow-object-detection-api) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->tensorflow-object-detection-api) (3.0.2)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (2.0.15)
# Requirement already satisfied: overrides>=5.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (1.8.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (23.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (0.18.1)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (1.8.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (0.12.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (0.21.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (0.5.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->tensorflow-object-detection-api) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (21.2.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (6.0.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (3.3.0)
# Requirement already satisfied: jsonschema[format-nongpl]>=4.18.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (4.23.0)
# Requirement already satisfied: referencing in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (0.36.2)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (0.1.1)
# Requirement already satisfied: rfc3339-validator in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (0.1.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (0.24.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (25.3.0)
# Requirement already satisfied: isoduration in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (20.11.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (24.11.1)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (1.3.0)
# Requirement already satisfied: fqdn in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (1.5.1)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tensorflow-object-detection-api) (0.12.0)
# Requirement already satisfied: requests>=2.31 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tensorflow-object-detection-api) (2.32.3)
# Requirement already satisfied: babel>=2.10 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tensorflow-object-detection-api) (2.17.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (1.5.1)
# Requirement already satisfied: bleach[css]!=5.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (6.2.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (4.13.4)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (3.1.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.10.2)
# Requirement already satisfied: defusedxml in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter->tensorflow-object-detection-api) (0.7.1)
# Requirement already satisfied: webencodings in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->tensorflow-object-detection-api) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->tensorflow-object-detection-api) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (2.21.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tensorflow-object-detection-api) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tensorflow-object-detection-api) (2.4.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->tensorflow-object-detection-api) (2.6)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tensorflow-object-detection-api) (2.9.0.20241206)
# Requirement already satisfied: pure-eval in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->tensorflow-object-detection-api) (2.2.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow->tensorflow-object-detection-api) (2.12.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (1.71.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (3.13.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (3.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (2.12.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (0.4.30)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (25.2.10)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (0.31.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (2.12.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (3.0.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (18.1.1)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (2.12.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (0.5.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (0.4.30)
# Requirement already satisfied: scipy>=1.9 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (1.15.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (0.7.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (3.1.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (2.39.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (3.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (4.9.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (5.5.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow->tensorflow-object-detection-api) (3.2.2)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (1.0.0)
# Requirement already satisfied: keyring>=15.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (25.6.0)
# Requirement already satisfied: readme-renderer>=35.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (44.0)
# Requirement already satisfied: rich>=12.0.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (14.0.0)
# Requirement already satisfied: rfc3986>=1.4.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (2.0.0)
# Requirement already satisfied: id in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from twine->tensorflow-object-detection-api) (1.5.0)
# Requirement already satisfied: importlib_metadata>=4.11.4 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (8.6.1)
# Requirement already satisfied: jaraco.functools in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (4.1.0)
# Requirement already satisfied: jaraco.classes in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (3.4.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (0.2.3)
# Requirement already satisfied: jaraco.context in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from keyring>=15.1->twine->tensorflow-object-detection-api) (6.0.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from importlib_metadata>=4.11.4->keyring>=15.1->twine->tensorflow-object-detection-api) (3.21.0)
# Requirement already satisfied: docutils>=0.21.2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (0.21.2)
# Requirement already satisfied: nh3>=0.2.14 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from readme-renderer>=35.0->twine->tensorflow-object-detection-api) (0.2.21)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from rich>=12.0.0->twine->tensorflow-object-detection-api) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->tensorflow-object-detection-api) (0.1.2)
# Requirement already satisfied: more-itertools in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jaraco.classes->keyring>=15.1->twine->tensorflow-object-detection-api) (10.6.0)
# Requirement already satisfied: backports.tarfile in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from jaraco.context->keyring>=15.1->twine->tensorflow-object-detection-api) (1.2.0)
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\ih20g\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: protobuf==3.20.3 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (3.20.3)
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\ih20g\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pycocotools in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (2.0.8)
# Requirement already satisfied: numpy in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from pycocotools) (1.23.5)
# Requirement already satisfied: matplotlib>=2.1.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from pycocotools) (3.10.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.1.0->pycocotools) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.1.0->pycocotools) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.1.0->pycocotools) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.1.0->pycocotools) (11.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.1.0->pycocotools) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.1.0->pycocotools) (1.4.8)
# Requirement already satisfied: six>=1.5 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.17.0)
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\ih20g\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ih20g\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\ih20g\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# fatal: destination path 'models' already exists and is not an empty directory.
# Could Not Find c:\Users\ih20g\weapon-detection-ai\models\setup.py

# %% [markdown]
# ## 2. Data Preparation
# Parse XML annotations and create TFRecords

# %%
import os
import xml.etree.ElementTree as ET
import pandas as pd
import tensorflow as tf
from object_detection.utils import dataset_util, label_map_util
from collections import namedtuple

# Define class labels based on your folders
CLASSES = {
    'gun': 1,
    'knife': 2,
    'hammer': 3,
    'bat': 4,
    'person': 5
}

def parse_xml(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()

    filename = root.find('filename').text
    width = int(root.find('size/width').text)
    height = int(root.find('size/height').text)

    objects = []
    for obj in root.findall('object'):
        label = obj.find('name').text.lower()
        if label == 'base ball bat':
            label = 'bat'
        bndbox = obj.find('bndbox')
        xmin = int(bndbox.find('xmin').text)
        ymin = int(bndbox.find('ymin').text)
        xmax = int(bndbox.find('xmax').text)
        ymax = int(bndbox.find('ymax').text)

        objects.append({
            'label': label,
            'xmin': xmin,
            'ymin': ymin,
            'xmax': xmax,
            'ymax': ymax
        })

    return {
        'filename': filename,
        'width': width,
        'height': height,
        'objects': objects
    }

# %% [markdown]
# ## 3. Create TFRecords
# Convert dataset to TensorFlow format

# %%
def create_tf_example(example, images_dir):
    img_path = os.path.join(images_dir, example['filename'])
    with tf.io.gfile.GFile(img_path, 'rb') as fid:
        encoded_jpg = fid.read()

    width = example['width']
    height = example['height']
    filename = example['filename'].encode('utf8')
    image_format = b'jpg'

    xmins = []
    xmaxs = []
    ymins = []
    ymaxs = []
    classes_text = []
    classes = []

    for obj in example['objects']:
        xmins.append(obj['xmin'] / width)
        xmaxs.append(obj['xmax'] / width)
        ymins.append(obj['ymin'] / height)
        ymaxs.append(obj['ymax'] / height)
        classes_text.append(obj['label'].encode('utf8'))
        classes.append(CLASSES[obj['label']])

    tf_example = tf.train.Example(features=tf.train.Features(feature={
        'image/height': dataset_util.int64_feature(height),
        'image/width': dataset_util.int64_feature(width),
        'image/filename': dataset_util.bytes_feature(filename),
        'image/source_id': dataset_util.bytes_feature(filename),
        'image/encoded': dataset_util.bytes_feature(encoded_jpg),
        'image/format': dataset_util.bytes_feature(image_format),
        'image/object/bbox/xmin': dataset_util.float_list_feature(xmins),
        'image/object/bbox/xmax': dataset_util.float_list_feature(xmaxs),
        'image/object/bbox/ymin': dataset_util.float_list_feature(ymins),
        'image/object/bbox/ymax': dataset_util.float_list_feature(ymaxs),
        'image/object/class/text': dataset_util.bytes_list_feature(classes_text),
        'image/object/class/label': dataset_util.int64_list_feature(classes),
    }))
    return tf_example

# %%
# Write TFRecord files
def generate_tfrecord_from_dataset(dataset_dir, output_path):
    writer = tf.io.TFRecordWriter(output_path)

    for class_folder in os.listdir(dataset_dir):
        folder_path = os.path.join(dataset_dir, class_folder)
        if not os.path.isdir(folder_path):
            continue

        for file in os.listdir(folder_path):
            if not file.endswith(".xml"):
                continue
            xml_path = os.path.join(folder_path, file)
            try:
                annotation = parse_xml(xml_path)
                tf_example = create_tf_example(annotation, folder_path)
                writer.write(tf_example.SerializeToString())
            except Exception as e:
                print(f"Skipping {xml_path}: {e}")

    writer.close()

# Example usage
#generate_tfrecords_from_dataset('images/train', 'annotations/train', 'train.record')
#generate_tfrecords_from_dataset('images/val', 'annotations/val', 'val.record')

# %% [markdown]
# ## 4. Generate Label Map

# %%
# !mkdir -p training
label_map_content = ""
for name, id in CLASSES.items():
    label_map_content += f'item {{\n  id: {id}\n  name: \"{name}\"\n}}\n\n'

with open('training/label_map.pbtxt', 'w') as f:
    f.write(label_map_content)

# %% [markdown]
# ## 5. Model Configuration

# %%
import os
import urllib.request
import tarfile
import shutil

# 1. Download the model
model_url = "http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz"
model_tar = "ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz"

if not os.path.exists(model_tar):
    print("Downloading model...")
    urllib.request.urlretrieve(model_url, model_tar)
else:
    print("Model already downloaded.")

# 2. Extract the tar.gz
model_dir = "ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8"
if not os.path.exists(model_dir):
    print("Extracting model...")
    with tarfile.open(model_tar) as tar:
        tar.extractall()
else:
    print("Model already extracted.")

# 3. Move 'checkpoint' folder to 'training/checkpoint'
os.makedirs("training", exist_ok=True)
src_checkpoint = os.path.join(model_dir, "checkpoint")
dst_checkpoint = os.path.join("training", "checkpoint")

if not os.path.exists(dst_checkpoint):
    shutil.move(src_checkpoint, dst_checkpoint)
    print("Checkpoint moved to training/")
else:
    print("Checkpoint already exists.")
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# !tar -xzf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# !mv ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint training/
# Out:
# Model already downloaded.
# Model already extracted.
# Checkpoint already exists.

# %%
# # Modify the pipeline.config
# !sed -i "s/num_classes: 90/num_classes: 5/g" ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# !sed -i "s|PATH_TO_BE_CONFIGURED/mscoco_label_map.pbtxt|training/label_map.pbtxt|g" ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# !sed -i "s|PATH_TO_BE_CONFIGURED/train.record|train.record|g" ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# !sed -i "s|PATH_TO_BE_CONFIGURED/val.record|val.record|g" ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config


config_path = "ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config"

# Read the config file
with open(config_path, "r") as f:
    config = f.read()

# Perform replacements
config = config.replace("num_classes: 90", "num_classes: 5")
config = config.replace("PATH_TO_BE_CONFIGURED/mscoco_label_map.pbtxt", "training/label_map.pbtxt")
config = config.replace("PATH_TO_BE_CONFIGURED/train.record", "train.record")
config = config.replace("PATH_TO_BE_CONFIGURED/val.record", "val.record")

# Save the updated config
with open(config_path, "w") as f:
    f.write(config)

print("✅ pipeline.config updated successfully.")
# Out:
# ✅ pipeline.config updated successfully.

# %% [markdown]
# ## 6. Start Training

# %%
# !python -m object_detection.model_main_tf2 \
    --pipeline_config_path=ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config \
    --model_dir=training/ \
    --alsologtostderr \
    --num_train_steps=10000 \
    --sample_1_of_n_eval_examples=1 \
    --num_eval_steps=500
# Out:
# c:\Users\ih20g\AppData\Local\Programs\Python\Python310\python.exe: No module named object_detection.model_main_tf2

# %% [markdown]
# ## 7. Export Trained Model

# %%
# import os
# import sys
# sys.path.append(os.path.abspath('models/research'))
# sys.path.append(os.path.abspath('models/research/slim'))

# !python -m object_detection.exporter_main_v2 \
#     --input_type image_tensor \
#     --pipeline_config_path ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config \
#     --trained_checkpoint_dir training/ \
#     --output_directory inference_graph

import os
import sys

# Add model directories to sys.path
sys.path.append(os.path.abspath('models/research'))
sys.path.append(os.path.abspath('models/research/slim'))
sys.path.append(os.path.abspath('models/research/object_detection'))

# Run the exporter module
# !python -m object_detection.exporter_main_v2 \
    --input_type image_tensor \
    --pipeline_config_path ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config \
    --trained_checkpoint_dir training/ \
    --output_directory inference_graph
# Out:
# c:\Users\ih20g\AppData\Local\Programs\Python\Python310\python.exe: No module named exporter_main_v2

# %% [markdown]
# ## 8. Verify Model

# %%
import cv2
import numpy as np
from object_detection.utils import visualization_utils as viz_utils

# Load saved model
model = tf.saved_model.load('inference_graph/saved_model')

def detect_objects(image_path):
    image = cv2.imread(image_path)
    input_tensor = tf.convert_to_tensor(image)
    input_tensor = input_tensor[tf.newaxis,...]

    detections = model(input_tensor)

    viz_utils.visualize_boxes_and_labels_on_image_array(
        image,
        detections['detection_boxes'][0].numpy(),
        detections['detection_classes'][0].numpy().astype(int),
        detections['detection_scores'][0].numpy(),
        label_map_util.create_category_index_from_labelmap('training/label_map.pbtxt'),
        use_normalized_coordinates=True,
        max_boxes_to_draw=5,
        min_score_thresh=0.5
    )

    cv2.imshow('Detection', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Test on a sample image
detect_objects('test_images/image_401.jpg')
